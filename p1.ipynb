# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.59  Python-3.11.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
# Setup complete  (16 CPUs, 7.7 GB RAM, 379.1/465.9 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="avKOdH27f74pfZkP8yjV")
project = rf.workspace("ai-solutions-nbzxp").project("facial-expression-ai-solution")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Facial-Expression---AI-Solution-1 in yolov8:: 100%|██████████| 9240/9240 [00:07<00:00, 1304.13it/s]

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')  # Path to your YOLOv8 model

# Train the model
model.train(
    data=r"C:\Users\rohan\Desktop\Project\CV\Facial-Expression---AI-Solution-1\data.yaml",  # Raw string to prevent escape issues
    epochs=8,          # Number of epochs
    imgsz=440,         # Image size
    batch=16           # Batch size
)
# Out:
# Ultralytics 8.3.59  Python-3.11.3 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
# ...

# %%
resdt = r"C:\Users\rohan\Desktop\Project\CV\runs\detect\train5"
from IPython.display import Image, display
display(Image(filename=f'{resdt}\\confusion_matrix.png'))

# %%
display(Image(filename=f'{resdt}\\results.png'))

# %%
import pandas as pd

df = pd.read_csv(f'{resdt}\\results.csv')

print(df.tail(2))
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   679.794         1.10924         2.43364         1.29973
# 1      2  1391.610         1.00871         1.73309         1.24010
# 2      3  2105.760         0.96995         1.56842         1.20716
# 3      4  2778.550         0.95082         1.47485         1.19237
# 4      5  3457.520         0.91795         1.38740         1.16777
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.26608            0.61812           0.35996
# 1               0.37443            0.69056           0.43991
# 2               0.42191            0.60883           0.52861
# 3               0.51186            0.62556           0.57749
# 4               0.52195            0.65055           0.61817
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.26037       1.08514       2.14377       1.35032  0.000302
# ...

# %%
wtpath=r"C:\Users\rohan\Desktop\Project\CV\runs\detect\train5\weights"

# %%
import os

# Define the path to your model and image
source_path = r"C:\Users\rohan\Desktop\Project\CV\Facial-Expression---AI-Solution-1\manual_testdata\Screenshot 2025-01-10 205630.png"

# Define the folder where results will be saved
results_folder = r"C:\Users\rohan\Desktop\Project\CV\DetectionResults"
name_folder = "output"  # Fixed folder name for results

# Construct the YOLO command
command = f'YOLO task=detect mode=predict model={wtpath}\\best.pt conf=0.25 source="{source_path}" save=True project="{results_folder}" name="{name_folder}"'

# Run the command
os.system(command)
# Out:
# 0
